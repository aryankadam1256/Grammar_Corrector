# %% [markdown]
# # Model Training (Google Colab)
#
# This is the Google Colab training notebook for fine-tuning **BART-base** (`facebook/bart-base`) on Grammatical Error Correction tasks.
#
# The notebook is designed to run on Colab with a GPU runtime and covers:
#
# 1. Environment setup and dependency installation
# 2. Dataset loading and preprocessing
# 3. BART-base fine-tuning with Hugging Face Transformers
# 4. Checkpoint saving and training monitoring
#
# **Runtime requirement:** GPU (T4 or better recommended)

# %%
# Placeholder: GPU availability check for Colab
import torch

if torch.cuda.is_available():
    device = torch.device("cuda")
    gpu_name = torch.cuda.get_device_name(0)
    gpu_memory = torch.cuda.get_device_properties(0).total_mem / (1024 ** 3)
    print(f"GPU available: {gpu_name} ({gpu_memory:.1f} GB)")
else:
    device = torch.device("cpu")
    print("WARNING: No GPU detected. Go to Runtime > Change runtime type > GPU.")

print(f"Using device: {device}")
